# %% [markdown]
# ### File for looking at indices of conf/correct events to see how many are neutral class.
# ## Europe.
#
# 8/18/2025

# %%
#relevant import statements
import numpy as np
import math
import pandas as pd
import xarray as xr 
import pickle 
import matplotlib.pyplot as plt

import collections

# %%
def daily_anomaly(target):
    dailymean = np.nanmean(target,axis=1)
    anom = np.zeros_like(target)
    for t in np.arange(target.shape[1]):
         anom[:,t] = target[:,t] - dailymean
    print(anom.shape)
    return anom; 

#_________________________________________________________________
##this instance is just to save the keys so that I can look at composites ... for those dates. 
def compare_keys(list1, list2):
    list1_count = collections.Counter() ##RF counter dictionary
    for day in list1:
        list1_count[day] += 1
    list2_count = collections.Counter() ##LSTM counter dictionary
    for day in list2:
        list2_count[day] += 1
        
    result = []
    list1only = []
    #begin comparing RF and LSTM dictionaries. 
    for key in list1_count:
        if key in list2_count:
            #save the key to look at for composites
            result.append(key)
        if key not in list2_count:
            list1only.append(key)
    
    list2only =[]
    for key in list2_count:
        if key not in list1_count:
            list2only.append(key)
    
    ##I have this set up to look at the SLTM/RF only values too but I may save those for another time. 
    return result, list1only, list2only;
#ultimately these composites would look at the average across the # of shared dates, ignoring the count of them.

# %%
##process ellipse diags.
##open ellipse metric files
infile = open("../../data/ellipse/wind10_redo.p", 'rb') 
wind10 = pickle.load(infile)
infile.close()

infile = open("../../data/ellipse/size10_redo.p", 'rb') 
size10 = pickle.load(infile)
infile.close()

infile = open("../../data/ellipse/ratio10_redo.p", 'rb') 
rat10 = pickle.load(infile)
infile.close()

infile = open("../../data/ellipse/ephi10_redo.p", 'rb') 
ephi10 = pickle.load(infile)
infile.close()

infile = open("../../data/ellipse/cenlat10_redo.p", 'rb')
cenlat10 = pickle.load(infile)
infile.close()

infile = open("../../data/ellipse/cenlon10_redo.p", 'rb')
cenlon10 = pickle.load(infile)
infile.close()

infile = open("../../data/gph/NA_gph_weightedANOM_100.p", 'rb') 
gph = pickle.load(infile)
infile.close()

infile = open("../../data/pv/CAP_pvu_weightedANOM.p", 'rb') 
pv = pickle.load(infile)
infile.close()

#remove leap year
##CHANGE IF NOT EXTENDED DATAQ BACK TO 120
wind10 = np.delete(wind10[:62],[151],1)
rat10 = np.delete(rat10[:62],[151],1)
cenlat10 = np.delete(cenlat10[:62],[151],1)
cenlon10 = np.delete(cenlon10[:62],[151],1)
size10 = np.delete(size10[:62],[151],1)
ephi10 = np.delete(ephi10[:62],[151],1)

shift = 14
#this is used to change the start date from October 19 to November 2nd... and just reduce the overall time observed.
#0 if no change. 

idx = 135

wind10 = wind10[:,19+shift:168]
rat10 = rat10[:,19+shift:168]
cenlat10 = cenlat10[:,19+shift:168]
cenlon10 = cenlon10[:,19+shift:168]
size10 = size10[:,19+shift:168]
ephi10 = ephi10[:,19+shift:168]
gph = gph[:62,19+shift:168]
pv = pv[:62,19+shift:168]

#remove NaNs
##CHANGE IF NOT EXTENDED DATA
test_comp = []
indices = np.isnan(wind10)
for i in range(0,62):
    for j in range(0,idx):
        if indices[i,j] != False:
            wind10[i,j] = 0
            rat10[i,j] = 0
            cenlat10[i,j] = 0
            cenlon10[i,j] = 0
            size10[i,j] = 0
            ephi10[i,j] = 0
            if i >= 57:
                test_comp.append((i,j))
            else:
                continue
                
input2 = np.empty((62,idx,4))

input2[:,:,2] = daily_anomaly(cenlat10[:62,:])
input2[:,:,1] = daily_anomaly(cenlon10[:62,:])
input2[:,:,3] = daily_anomaly(wind10[:62,:])
input2[:,:,0] = daily_anomaly(gph[:62,:])
# Out:
# (62, 135)
# (62, 135)
# (62, 135)
# (62, 135)

# %% [markdown]
# Open index files and temp files.

# %%
##open indice files
infile = open("../posXtest_eur14.p", 'rb') 
posXtest = pickle.load(infile)
infile.close()

infile = open("../FposXtest_eur14.p", 'rb') 
FposXtest = pickle.load(infile)
infile.close()

infile = open("../negXtest_eur14.p", 'rb') 
negXtest = pickle.load(infile)
infile.close()

infile = open("../FnegXtest_eur14.p", 'rb') 
FnegXtest = pickle.load(infile)
infile.close()

infile = open("../../data/eur_anomtemps_3.p", 'rb') 
temps = pickle.load(infile)
infile.close()

temps = temps.reshape((62,149))
temp = temps[52:,14:]

# %%
temp.shape
# Out:
# (10, 135)

# %% [markdown]
# ### These few cells will be for making box plots instead lol.
#
# It is important to keep in mind that there are also just proportionally less pos and neg temp extremes left as I increase the classification criterion (i.e., +1.5 std) ... SO regardless of whether they are proportionally more events, there are still less to choose from ... if that makes sense?

# %%
##reduce input to just the testing data
nolag_Xtest = input2[52:,:,:]
nolag_Xtest.shape
####now I wanna make these plots SO ... I am adding an index column on to X_test ... full version. 
ranges = np.array([x for x in range(0,135*10,1)])
ranges = ranges.reshape(10,135) 
ranges.shape
# Out:
# (10, 135)

# %%
##Correct Positive Events
negcorr_indices = []
poscorr_indices = []
neutcorrP_indices = []
pos_corr_events = []
neut_corrP_events = []


for i in range(0,10):
    for j in range(0,135):
        #index for the date being observed
        date_index = ranges[i,j]
        ##loop through indexes of positive and correct events
        for k in range(len(posXtest)):
            pos_index = posXtest[k]
            if pos_index == date_index:
                value = temp[i,j] 
                if value == 0:
                    negcorr_indices.append(pos_index)
                if value == 1:
                    poscorr_indices.append(pos_index)
                    pos_corr_events.extend(nolag_Xtest[i,j,:])
                if value == 2:
                    neutcorrP_indices.append(pos_index)
                    neut_corrP_events.extend(nolag_Xtest[i,j,:])
                    
print("Number of Positive and Correct, Positive Temp Anoms: ",str(len(pos_corr_events)))
print("Number of Positive and Correct, Neutral Temp Anoms: ",str(len(neut_corrP_events)))

count, true, neut = compare_keys(poscorr_indices, neutcorrP_indices)
print("There are "+str(len(count))+" shared indices. There are "+str(len(true))+" unique events for True Positives and "+str(len(neut))+" for neutral.")

Tpos = np.array(pos_corr_events).reshape((len(poscorr_indices),1,4))
print(Tpos.shape)

Tpos_N = np.array(neut_corrP_events).reshape((len(neutcorrP_indices),1,4))
print(Tpos_N.shape)
# Out:
# Number of Positive and Correct, Positive Temp Anoms:  34392
# Number of Positive and Correct, Neutral Temp Anoms:  11152
# There are 0 shared indices. There are 155 unique events for True Positives and 71 for neutral.
# (8598, 1, 4)
# (2788, 1, 4)

# %%
##Correct Negative Events
negcorr_indices = []
poscorr_indices = []
neutcorrN_indices = []
neg_corr_events = []
neut_corrN_events = []

neg_corr_num = []
neut_corr_num = []

for i in range(0,10):
    for j in range(0,135):
        #index for the date being observed
        date_index = ranges[i,j]
        ##loop through indexes of positive and correct events
        for k in range(len(negXtest)):
            pos_index = negXtest[k]
            if pos_index == date_index:
                value = temp[i,j] 
                if value == 0:
                    negcorr_indices.append(pos_index)
                    neg_corr_events.extend(nolag_Xtest[i,j,:])
                if value == 1:
                    poscorr_indices.append(pos_index)
                if value == 2:
                    neutcorrN_indices.append(pos_index)
                    neut_corrN_events.extend(nolag_Xtest[i,j,:])
                    
print("Number of Negative and Correct, Negative Temp Anoms: ",str(len(negcorr_indices)))
print("Number of Negative and Correct, Neutral Temp Anoms: ",str(len(neutcorrN_indices)))

count, true, neut = compare_keys(negcorr_indices, neutcorrN_indices)
print("There are "+str(len(count))+" shared indices. There are "+str(len(true))+" unique events for True Negatives and "+str(len(neut))+" for neutral.")

Tneg = np.array(neg_corr_events).reshape((len(negcorr_indices),1,4))
print(Tneg.shape)

Tneg_N = np.array(neut_corrN_events).reshape((len(neutcorrN_indices),1,4))
print(Tneg_N.shape)
# Out:
# Number of Negative and Correct, Negative Temp Anoms:  6259
# Number of Negative and Correct, Neutral Temp Anoms:  3551
# There are 0 shared indices. There are 147 unique events for True Negatives and 84 for neutral.
# (6259, 1, 4)
# (3551, 1, 4)

# %%
##False Positive Events
Fnegcorr_indices = []
Fposcorr_indices = []
FneutcorrP_indices = []
Fpos_corr_events = []
Fneut_corrP_events = []

for i in range(0,10):
    for j in range(0,135):
        #index for the date being observed
        date_index = ranges[i,j]
        ##loop through indexes of positive and correct events
        for k in range(len(FposXtest)):
            pos_index = FposXtest[k]
            if pos_index == date_index:
                value = temp[i,j] 
                if value == 0:
                    Fnegcorr_indices.append(pos_index)
                    Fpos_corr_events.extend(nolag_Xtest[i,j,:])
                if value == 1:
                    Fposcorr_indices.append(pos_index)
                if value == 2:
                    FneutcorrP_indices.append(pos_index)
                    Fneut_corrP_events.extend(nolag_Xtest[i,j,:])
                    
print("Number of Positive and False, Negative Temp Anoms: ",str(len(Fnegcorr_indices)))
print("Number of Positive and False, Neutral Temp Anoms: ",str(len(FneutcorrP_indices)))

count, true, neut = compare_keys(Fnegcorr_indices, FneutcorrP_indices)
print("There are "+str(len(count))+" shared indices. There are "+str(len(true))+" unique events for False Positives and "+str(len(neut))+" for neutral.")

Fpos = np.array(Fpos_corr_events).reshape((len(Fnegcorr_indices),1,4))
print(Fpos.shape)

Fpos_N = np.array(Fneut_corrP_events).reshape((len(FneutcorrP_indices),1,4))
print(Fpos_N.shape)
# Out:
# Number of Positive and False, Negative Temp Anoms:  935
# Number of Positive and False, Neutral Temp Anoms:  1178
# There are 0 shared indices. There are 37 unique events for False Positives and 39 for neutral.
# (935, 1, 4)
# (1178, 1, 4)

# %%
##False Negative Events
Fnegcorr_indices = []
Fposcorr_indices = []
FneutcorrN_indices = []
Fneg_corr_events = []
Fneut_corrN_events = []


for i in range(0,10):
    for j in range(0,135):
        #index for the date being observed
        date_index = ranges[i,j]
        ##loop through indexes of positive and correct events
        for k in range(len(FnegXtest)):
            pos_index = FnegXtest[k]
            if pos_index == date_index:
                value = temp[i,j] 
                if value == 0:
                    Fnegcorr_indices.append(pos_index)
                if value == 1:
                    Fposcorr_indices.append(pos_index)
                    Fneg_corr_events.extend(nolag_Xtest[i,j,:])
                if value == 2:
                    FneutcorrN_indices.append(pos_index)
                    Fneut_corrN_events.extend(nolag_Xtest[i,j,:])
                    
print("Number of Negative and False, Positive Temp Anoms: ",str(len(Fposcorr_indices)))
print("Number of Positive and False, Neutral Temp Anoms: ",str(len(FneutcorrN_indices)))
count, true, neut = compare_keys(Fposcorr_indices, FneutcorrN_indices)
print("There are "+str(len(count))+" shared indices. There are "+str(len(true))+" unique events for False Negatives and "+str(len(neut))+" for neutral.")

Fneg = np.array(Fneg_corr_events).reshape((len(Fposcorr_indices),1,4))
print(Fneg.shape)

Fneg_N = np.array(Fneut_corrN_events).reshape((len(FneutcorrN_indices),1,4))
print(Fneg_N.shape)
# Out:
# Number of Negative and False, Positive Temp Anoms:  1004
# Number of Positive and False, Neutral Temp Anoms:  2685
# There are 0 shared indices. There are 35 unique events for False Negatives and 69 for neutral.
# (1004, 1, 4)
# (2685, 1, 4)

# %%
import matplotlib.ticker as mticker
myLocator = mticker.MultipleLocator(2)

#metrics = ["Wind (m/s)", "Ratio (m)", "Latitude ($^o$)", "Longitude ($^o$)", "Size (m$^2$)", "EPhi ($^o$)", "GPH (hPa)", "PV (m$^2$K/s kg)"]
metrics = ["GPH (m)", "Longitude ($^o$)", "Latitude ($^o$)","Wind (m/s)"]
y1 = [-400,-200,-80,-50]
y2 = [400,200,20,50]
ticks = ['True +', 'False -', 'True -', 'False +'] #set tick numbers for dataset
ind = [2, 4, 6, 8]  # the x locations for the groups
w = 0.25 #box-plot width
c = ["midnightblue","royalblue","mediumvioletred","magenta"]
fs = 14

fig, axes = plt.subplots(4, 1, figsize=(12, 12))
plt.suptitle("Distribution of RF Input Feature Anomalies, Europe +14 Days", fontsize = 18, x=0.53)
axes = axes.flatten()
for i in range(0,4):
    C_pos = Tpos[:,0,i]
    F_neg = Fneg[:,0,i]
    C_neg = Tneg[:,0,i]
    F_pos = Fpos[:,0,i]
        
    a1 =axes[i].boxplot([C_pos,F_neg,C_neg,F_pos], positions= [2,4,6,8], widths=w, patch_artist=True)
    for bplot in (a1,):
        for patch, color in zip(bplot['boxes'], c):
            patch.set_facecolor(color)
    axes[i].set_xticks(ind, ticks, fontsize = 14)
    axes[i].set_ylim((y1[i],y2[i]))
    axes[i].set_ylabel(str(metrics[i]), fontsize = 14)
    axes[i].tick_params(axis='both', labelsize=14)

plt.tight_layout()
plt.subplots_adjust(top=0.95)   
#plt.savefig("EurRF_BOXPLOT_14days.png",bbox_inches = 'tight')
plt.show()

# %%
import matplotlib.ticker as mticker
myLocator = mticker.MultipleLocator(2)

#metrics = ["Wind (m/s)", "Ratio (m)", "Latitude ($^o$)", "Longitude ($^o$)", "Size (m$^2$)", "EPhi ($^o$)", "GPH (hPa)", "PV (m$^2$K/s kg)"]
metrics = ["GPH (m)", "Longitude ($^o$)", "Latitude ($^o$)","Wind (m/s)"]
y1 = [-400,-200,-80,-50]
y2 = [400,200,20,50]
ticks = ['True +', 'False -', 'True -', 'False +'] #set tick numbers for dataset
ind = [2, 4, 6, 8]  # the x locations for the groups
w = 0.25 #box-plot width
c = ["midnightblue","royalblue","mediumvioletred","magenta"]
fs = 14

fig, axes = plt.subplots(4, 1, figsize=(12, 12))
plt.suptitle("Distribution of RF Input Feature Anomalies, Europe +14 Days", fontsize = 18, x=0.53)
axes = axes.flatten()
for i in range(0,4):
    C_pos = Tpos_N[:,0,i]
    F_neg = Fneg_N[:,0,i]
    C_neg = Tneg_N[:,0,i]
    F_pos = Fpos_N[:,0,i]
        
    a1 =axes[i].boxplot([C_pos,F_neg,C_neg,F_pos], positions= [2,4,6,8], widths=w, patch_artist=True)
    for bplot in (a1,):
        for patch, color in zip(bplot['boxes'], c):
            patch.set_facecolor(color)
    axes[i].set_xticks(ind, ticks, fontsize = 14)
    axes[i].set_ylim((y1[i],y2[i]))
    axes[i].set_ylabel(str(metrics[i]), fontsize = 14)
    axes[i].tick_params(axis='both', labelsize=14)

plt.tight_layout()
plt.subplots_adjust(top=0.95)   
#plt.savefig("EurRF_BOXPLOT_14days.png",bbox_inches = 'tight')
plt.show()
